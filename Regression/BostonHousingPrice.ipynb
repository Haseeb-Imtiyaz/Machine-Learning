# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set()

# %%
df=pd.read_csv('HousingData.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#Duplicate value
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe().round(2)
# Out:
#          CRIM      ZN   INDUS    CHAS     NOX      RM     AGE     DIS     RAD  \
# count  486.00  486.00  486.00  486.00  506.00  506.00  486.00  506.00  506.00
# mean     3.61   11.21   11.08    0.07    0.55    6.28   68.52    3.80    9.55
# std      8.72   23.39    6.84    0.26    0.12    0.70   28.00    2.11    8.71
# min      0.01    0.00    0.46    0.00    0.38    3.56    2.90    1.13    1.00
# 25%      0.08    0.00    5.19    0.00    0.45    5.89   45.18    2.10    4.00
# 50%      0.25    0.00    9.69    0.00    0.54    6.21   76.80    3.21    5.00
# 75%      3.56   12.50   18.10    0.00    0.62    6.62   93.98    5.19   24.00
# max     88.98  100.00   27.74    1.00    0.87    8.78  100.00   12.13   24.00
#
#           TAX  PTRATIO       B   LSTAT    MEDV
# count  506.00   506.00  506.00  486.00  506.00
# mean   408.24    18.46  356.67   12.72   22.53
# std    168.54     2.16   91.29    7.16    9.20
# min    187.00    12.60    0.32    1.73    5.00
# ...

# %%
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
# Mode returns 2 value
for i in df.columns:
    df[i].fillna(df[i].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.skew()
# Out:
# CRIM       5.318370
# ZN         2.302295
# INDUS      0.309871
# CHAS       3.450763
# NOX        0.729308
# RM         0.403612
# AGE       -0.594261
# DIS        1.011781
# RAD        1.004815
# TAX        0.669956
# PTRATIO   -0.802325
# B         -2.890374
# LSTAT      0.927291
# MEDV       1.108098
# dtype: float64

# %%
def boxplots(col):
    sns.boxplot(df[col])
    plt.title(col)
    plt.show()
for i in list(df.select_dtypes(exclude=['object'])):
    boxplots(i)

# %%
# corr
df.corr().round(2)
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.18   0.39 -0.05  0.41 -0.22  0.34 -0.37  0.61  0.57     0.27
# ZN      -0.18  1.00  -0.51 -0.04 -0.50  0.32 -0.54  0.64 -0.31 -0.31    -0.40
# INDUS    0.39 -0.51   1.00  0.06  0.74 -0.38  0.61 -0.70  0.59  0.72     0.38
# CHAS    -0.05 -0.04   0.06  1.00  0.07  0.10  0.08 -0.09  0.00 -0.03    -0.11
# NOX      0.41 -0.50   0.74  0.07  1.00 -0.30  0.71 -0.77  0.61  0.67     0.19
# RM      -0.22  0.32  -0.38  0.10 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.34 -0.54   0.61  0.08  0.71 -0.24  1.00 -0.72  0.45  0.50     0.26
# DIS     -0.37  0.64  -0.70 -0.09 -0.77  0.21 -0.72  1.00 -0.49 -0.53    -0.23
# RAD      0.61 -0.31   0.59  0.00  0.61 -0.21  0.45 -0.49  1.00  0.91     0.46
# TAX      0.57 -0.31   0.72 -0.03  0.67 -0.29  0.50 -0.53  0.91  1.00     0.46
# PTRATIO  0.27 -0.40   0.38 -0.11  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
sns.heatmap(df.corr().round(2))
# Out:
# <Axes: >

# %%
#to check multicolinearity in regeression
corr_matrix=df.corr().round(2)
corr_matrix[np.abs(corr_matrix)>0.65]
# Out:
#          CRIM   ZN  INDUS  CHAS   NOX   RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM      1.0  NaN    NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      NaN
# ZN        NaN  1.0    NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      NaN
# INDUS     NaN  NaN   1.00   NaN  0.74  NaN   NaN -0.70   NaN  0.72      NaN
# CHAS      NaN  NaN    NaN   1.0   NaN  NaN   NaN   NaN   NaN   NaN      NaN
# NOX       NaN  NaN   0.74   NaN  1.00  NaN  0.71 -0.77   NaN  0.67      NaN
# RM        NaN  NaN    NaN   NaN   NaN  1.0   NaN   NaN   NaN   NaN      NaN
# AGE       NaN  NaN    NaN   NaN  0.71  NaN  1.00 -0.72   NaN   NaN      NaN
# DIS       NaN  NaN  -0.70   NaN -0.77  NaN -0.72  1.00   NaN   NaN      NaN
# RAD       NaN  NaN    NaN   NaN   NaN  NaN   NaN   NaN  1.00  0.91      NaN
# TAX       NaN  NaN   0.72   NaN  0.67  NaN   NaN   NaN  0.91  1.00      NaN
# PTRATIO   NaN  NaN    NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      1.0
# ...

# %%
# Rule: No or little multicolinearity occurs in Regression model: IV is highly correlated coz it will make difficult to detrmine
# affetct of each variable on DV
# can also use VIF(varaince Inflation factor) vif > 5 to check multicoleniarity

# %% [markdown]
# #### outlier treatemennt

# %%
# crim,zn,rad,b : These are the columns where outlier is present we checked by analysing describe and boxplot

# %%
# no correcting outlier manually

# %%
df['CRIM'].describe()
# Out:
# count    506.000000
# mean       3.611874
# std        8.545770
# min        0.006320
# 25%        0.083235
# 50%        0.290250
# 75%        3.611874
# max       88.976200
# Name: CRIM, dtype: float64

# %%
Q1=0.068907
Q3=2.808720
IQR=Q3-Q1
upper_bound=Q3+1.5*IQR
df["CRIM"]=np.where(df["CRIM"]>upper_bound,upper_bound,df["CRIM"])

# %%
df['ZN'].describe()
# Out:
# count    506.000000
# mean      11.211934
# std       22.921051
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       11.211934
# max      100.000000
# Name: ZN, dtype: float64

# %%
Q1=0.000000
Q3=11.211934
IQR=Q3-Q1
upper_bound=Q3+1.5*IQR
df["ZN"]=np.where(df["ZN"]>upper_bound,upper_bound,df["ZN"])

# %%
df['ZN'].describe()
# Out:
# count    506.000000
# mean       6.523256
# std       10.810961
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       11.211934
# max       28.029835
# Name: ZN, dtype: float64

# %%
df['B'].describe()
# Out:
# count    506.000000
# mean     356.674032
# std       91.294864
# min        0.320000
# 25%      375.377500
# 50%      391.440000
# 75%      396.225000
# max      396.900000
# Name: B, dtype: float64

# %%
Q1=375.377500
Q3=396.225000
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
df["B"]=np.where(df["B"]<lower_bound,lower_bound,df["B"])

# %%
df['B'].describe()
# Out:
# count    506.000000
# mean     381.918836
# std       19.054913
# min      344.106250
# 25%      375.377500
# 50%      391.440000
# 75%      396.225000
# max      396.900000
# Name: B, dtype: float64

# %%
# Now check again
def boxplots(col):
    sns.boxplot(df[col])
    plt.title(col)
    plt.show()
for i in list(df.select_dtypes(exclude=['object'])):
    boxplots(i)

# %%
# split data
X=df.drop(columns=['MEDV'],axis=1)
y=df['MEDV']

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT
# 0       15.3  396.90   4.980000
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# ### Scaling in Regression

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(X)
x_scaled=pd.DataFrame(x_scaled,columns=X.columns)
x_scaled
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM           AGE  \
# 0   -0.737487  1.062635 -1.311010 -0.279851 -0.144217  0.413672 -1.210593e-01
# 1   -0.729508 -0.603990 -0.599771 -0.279851 -0.740262  0.194274  3.787156e-01
# 2   -0.729516 -0.603990 -0.599771 -0.279851 -0.740262  1.282714 -2.706270e-01
# 3   -0.727585 -0.603990 -1.330435 -0.279851 -0.835284  1.016303 -8.287698e-01
# 4   -0.713641 -0.603990 -1.330435 -0.279851 -0.835284  1.228577 -5.223385e-01
# ..        ...       ...       ...       ...       ...       ...           ...
# 501 -0.716082 -0.603990  0.126411 -0.279851  0.158124  0.439316  2.121240e-02
# 502 -0.722681 -0.603990  0.126411 -0.279851  0.158124 -0.234548  2.984598e-01
# 503 -0.716793 -0.603990  0.126411 -0.279851  0.158124  0.984960  8.201227e-01
# 504 -0.698231 -0.603990  0.126411 -0.279851  0.158124  0.725672  7.581068e-01
# 505 -0.721867 -0.603990  0.126411 -0.279851  0.158124 -0.362767  5.184109e-16
#
# ...

# %% [markdown]
# ### VIF-  >  5 Outlier

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif_score']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features']=x_scaled.columns
vif
# Out:
#     vif_score features
# 0    8.649757     CRIM
# 1    2.288969       ZN
# 2    3.640906    INDUS
# 3    1.063359     CHAS
# 4    4.296835      NOX
# 5    1.825443       RM
# 6    2.712446      AGE
# 7    3.805690      DIS
# 8   12.268856      RAD
# 9    8.571263      TAX
# 10   1.937560  PTRATIO
# 11   1.342770        B
# 12   2.606838    LSTAT

# %%
# remove the highest one and check again
x_scaled.drop(columns=['RAD'],axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Score']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features']=x_scaled.columns
vif
# Out:
#        Score features
# 0   4.756160     CRIM
# 1   2.288969       ZN
# 2   3.501532    INDUS
# 3   1.049374     CHAS
# 4   4.296584      NOX
# 5   1.805029       RM
# 6   2.698975      AGE
# 7   3.795365      DIS
# 8   5.718655      TAX
# 9   1.803134  PTRATIO
# 10  1.341548        B
# 11  2.591971    LSTAT

# %% [markdown]
# ### Multicolinearity is droped    Preprocessing done--------------------

# %% [markdown]
# ## EDA using DTale

# %%
# import dtale
# dtale.show(df)

# %% [markdown]
# ### EDA using Pandas-profiling

# %%
# from  ydata_profiling import ProfileReport
# profile=ProfileReport(df,title='EDA of Hosing Data')
# profile.to_file('eda_housing.html')

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#         CRIM         ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 42   0.14150   0.000000   6.91   0.0  0.448  6.169   6.6  5.7209    3  233
# 58   0.15445  25.000000   5.13   0.0  0.453  6.145  29.2  7.8148    8  284
# 385  6.91844   0.000000  18.10   0.0  0.700  5.277  98.1  1.4261   24  666
# 78   0.05646   0.000000  12.83   0.0  0.437  6.232  53.7  5.0141    5  398
# 424  6.91844   0.000000  18.10   0.0  0.584  5.565  70.6  2.0635   24  666
# ..       ...        ...    ...   ...    ...    ...   ...     ...  ...  ...
# 255  0.03548  28.029835   3.64   0.0  0.392  5.876  19.1  9.2203    1  315
# 72   0.09164   0.000000  10.81   0.0  0.413  6.065   7.8  5.2873    4  305
# 396  5.87205   0.000000  18.10   0.0  0.693  6.405  96.0  1.6768   24  666
# 235  0.33045   0.000000   6.20   0.0  0.507  6.086  61.5  3.6519    8  307
# 37   0.08014   0.000000   5.96   0.0  0.499  5.850  41.5  3.9342    5  279
#
#      PTRATIO          B  LSTAT
# 42      17.9  383.37000   5.81
# ...

# %% [markdown]
# ## -----> OLS Regression

# %%
from statsmodels.regression.linear_model import OLS
import statsmodels.regression.linear_model as smf

# %%
regression=smf.OLS(endog=y_train,exog=X_train).fit()
regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              661.8
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):                   6.94e-257
# Time:                        00:43:16   Log-Likelihood:                         -1228.0
# No. Observations:                 404   AIC:                                      2482.
# Df Residuals:                     391   BIC:                                      2534.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Evaluation for OLS

# %%
y_test_pred=regression.predict(X_test)
y_train_pred=regression.predict(X_train)

# %%
from sklearn.metrics import r2_score
print('Test Data Accuracy using OLS: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using OLS: ',r2_score(y_train,y_train_pred))
# Out:
# Test Data Accuracy using OLS:  0.7511281436272734
# Train Data Accuracy using OLS:  0.6835690802886487

# %% [markdown]
# ## -----> Regularisation Techniques

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
rid=Ridge(alpha=0.3)
las=Lasso(alpha=0.3)
ela=ElasticNet(alpha=0.3,l1_ratio=0.3)

# %%
rid.fit(X_train,y_train)
las.fit(X_train,y_train)
ela.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=0.3, l1_ratio=0.3)

# %% [markdown]
# #### Evaluation for Ridge, Lasso and ElasticNet

# %%
y_test_pred=rid.predict(X_test)
y_train_pred=rid.predict(X_train)
print('Test Data Accuracy using Ridge : ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using Ridge: ',r2_score(y_train,y_train_pred))
y_test_pred=las.predict(X_test)
y_train_pred=las.predict(X_train)
print('\nTest Data Accuracy using Lasso: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using Lasso: ',r2_score(y_train,y_train_pred))
y_test_pred=ela.predict(X_test)
y_train_pred=ela.predict(X_train)
print('\nTest Data Accuracy using ElasticNet: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using ElasticNet: ',r2_score(y_train,y_train_pred))
# Out:
# Test Data Accuracy using Ridge :  0.737265346777166
# Train Data Accuracy using Ridge:  0.7058033110992199
#
# Test Data Accuracy using Lasso:  0.6994603231859045
# Train Data Accuracy using Lasso:  0.6821521223843233
#
# Test Data Accuracy using ElasticNet:  0.6815109092300788
# Train Data Accuracy using ElasticNet:  0.6787834721386474

# %% [markdown]
# ## -----> Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Evaluation for Random Forest Regression

# %%
y_test_pred=rf.predict(X_test)
y_train_pred=rf.predict(X_train)
print('\nTest Data Accuracy using RandomForestRegressor: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using RandomForestRegressor: ',r2_score(y_train,y_train_pred))
# Out:
# Test Data Accuracy using RandomForestRegressor:  0.882013653594452
# Train Data Accuracy using RandomForestRegressor:  0.9807670079029674

# %% [markdown]
# ##  -----> Gradient Descent Regression

# %%
from sklearn.linear_model import SGDRegressor
grd=SGDRegressor()
grd.fit(X_train,y_train)
# Out:
# SGDRegressor()

# %%
y_test_pred=grd.predict(X_test)
y_train_pred=grd.predict(X_train)
print('\nTest Data Accuracy using SGDRegressor: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using SGDRegressor: ',r2_score(y_train,y_train_pred))
# Out:
# Test Data Accuracy using SGDRegressor:  -1.5841202965929134e+26
# Train Data Accuracy using SGDRegressor:  -1.8003591225064777e+26

# %% [markdown]
# ###### NOTE:
# The result in Gradient Descent will be pathetic because first we need to scale the data then only we can use Gradient Descent Regression

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaled_train=scaler.fit_transform(X_train)
X_scaled_test=scaler.fit_transform(X_test)

# %%
grd.fit(X_scaled_train,y_train)
# Out:
# SGDRegressor()

# %% [markdown]
# #### Evalution for Gradient Descent Regression

# %%
y_test_pred=grd.predict(X_scaled_test)
y_train_pred=grd.predict(X_scaled_train)
print('\nTest Data Accuracy using SGDRegressor: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using SGDRegressor: ',r2_score(y_train,y_train_pred))
# Out:
# Test Data Accuracy using SGDRegressor:  0.7379791740327597
# Train Data Accuracy using SGDRegressor:  0.7034311843310854

# %% [markdown]
# ## -----> Decision Tree Regression
# Note: DT is mosly used for classsifiaction purpose

# %%
from sklearn.tree import DecisionTreeRegressor
dtree=DecisionTreeRegressor()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# #### Evalution for DecisionTreeRegressor

# %%
y_test_pred=dtree.predict(X_test)
y_train_pred=dtree.predict(X_train)
print('\nTest Data Accuracy using DecisionTreeRegressor: ',r2_score(y_test,y_test_pred))
print('Train Data Accuracy using DecisionTreeRegressor: ',r2_score(y_train,y_train_pred))
# Out:
# Test Data Accuracy using DecisionTreeRegressor:  0.8325878883348938
# Train Data Accuracy using DecisionTreeRegressor:  1.0

# %% [markdown]
# ##### Note: Here overfitting is occured

# %% [markdown]
# ## ----> Assumptions of Linear Regression

# %% [markdown]
# #### 1) Linearity:
#         Graph of Y_train and predicted Y should be linear
#         if not linear then it may be a polynomial Regression Problem

# %%
sns.scatterplot(x=y_train,y=x_train_pred)
plt.show()

# %% [markdown]
# #### 2) No or little multicolinearity:
#         The independent variables should not depend on each other
#         check using Variance Inflation Factor (VIF) > 5

# %% [markdown]
# #### 3) No Hetroscadicity:
#         The distribution plot should be normaly distributed

# %%
sns.displot((y_train-y_train_pred),bins=50)
plt.show()

# %% [markdown]
# #### 4) No autocorrelation:
#         Check of Durbin watson constant in OLS
#        if 1.5 < DW < 2.5 it is a Regression problem
#        else a Time Series problem
#             ARIMA , AutoRegressor can be used for Time Series

# %% [markdown]
# #### 5) No Endoginity:
#
#         The correct Independent Variable should be selected

# %% [markdown]
# #### 6) Normality of Residual
