# %% [markdown]
# # Titanic prediction using LogisticRegerssion

# %%
import pandas as pd

# %%
df=pd.read_csv('titanic_dataset.csv')

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         180
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       706
# Embarked      2
# dtype: int64

# %%
df[['Embarked','Sex']]
# Out:
#     Embarked     Sex
# 0          S    male
# 1          C  female
# 2          S  female
# 3          S  female
# 4          S    male
# ..       ...     ...
# 910        S    male
# 911        S  female
# 912        S  female
# 913        Q    male
# 914        S    male
#
# [915 rows x 2 columns]

# %%
df['Sex']=df['Sex'].astype('category')
df['Sex']=df['Sex'].cat.codes

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 910         0       3                        Andersson, Mr. Anders Johan
# 911         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 912         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 913         0       3                               Rice, Master. Eugene
# 914         1       2                       Williams, Mr. Charles Eugene
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 910         0       3                        Andersson, Mr. Anders Johan    1
# 911         0       3               Vestrom, Miss. Hulda Amanda Adolfina    0
# 912         1       2                   Hewlett, Mrs. (Mary D Kingcome)     0
# 913         0       3                               Rice, Master. Eugene    1
# 914         1       2                       Williams, Mr. Charles Eugene    1
#
# ...

# %%
df['Embarked']=df['Embarked'].astype('category')
df['Embarked']=df['Embarked'].cat.codes

# %%
import  matplotlib as plt
import seaborn as sns

# %%
sns.boxplot(data=df,x=df['Pclass'],y=df['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
import numpy as np

# %%
Q3=np.percentile(df['Age'],75)
Q1=np.percentile(df['Age'],25)

# %%
IQR=Q3-Q1

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR

# %%
upper_limit
# Out:
# np.float64(54.5)

# %%
lower_limit
# Out:
# np.float64(2.5)

# %%
df['Age'].describe()
# Out:
# count    915.000000
# mean      29.376142
# std       13.081513
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df[((df['Age']>(upper_limit)) | (df['Age']<(lower_limit)))]
# Out:
#      Survived  Pclass                                           Name  Sex  \
# 7           0       3                 Palsson, Master. Gosta Leonard    1
# 11          1       1                       Bonnell, Miss. Elizabeth    0
# 15          1       2               Hewlett, Mrs. (Mary D Kingcome)     0
# 16          0       3                           Rice, Master. Eugene    1
# 33          0       2                          Wheadon, Mr. Edward H    1
# ..        ...     ...                                            ...  ...
# 851         0       3                            Svensson, Mr. Johan    1
# 879         1       1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)    0
# 908         1       1                       Bonnell, Miss. Elizabeth    0
# 912         1       2               Hewlett, Mrs. (Mary D Kingcome)     0
# 913         0       3                           Rice, Master. Eugene    1
#
#       Age  SibSp  Parch      Ticket     Fare Cabin  Embarked
# ...

# %%
cleaned_data
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 907         1       3                    Sandstrom, Miss. Marguerite Rut    0
# 909         0       3                     Saundercock, Mr. William Henry    1
# 910         0       3                        Andersson, Mr. Anders Johan    1
# 911         0       3               Vestrom, Miss. Hulda Amanda Adolfina    0
# 914         1       2                       Williams, Mr. Charles Eugene    1
#
# ...

# %%
sns.boxplot(data=cleaned_data,x=cleaned_data['Pclass'],y=cleaned_data['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
cleaned_data.drop(['Cabin'],axis=1,inplace=True)
# Out:
# C:\Users\pumas\AppData\Local\Temp\ipykernel_13344\3599510670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data.drop(['Cabin'],axis=1,inplace=True)

# %%
cleaned_data.drop(['Name','Ticket'],axis=1,inplace=True)
# Out:
# C:\Users\pumas\AppData\Local\Temp\ipykernel_13344\3737080326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data.drop(['Name','Ticket'],axis=1,inplace=True)

# %%
cleaned_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.0      1      0   7.2500         2
# 1           1       1    0  38.0      1      0  71.2833         0
# 2           1       3    0  26.0      0      0   7.9250         2
# 3           1       1    0  35.0      1      0  53.1000         2
# 4           0       3    1  35.0      0      0   8.0500         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 907         1       3    0   4.0      1      1  16.7000         2
# 909         0       3    1  20.0      0      0   8.0500         2
# 910         0       3    1  39.0      1      5  31.2750         2
# 911         0       3    0  14.0      0      0   7.8542         2
# 914         1       2    1  28.0      0      0  13.0000         2
#
# [846 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(cleaned_data.loc[:,cleaned_data.columns!='Survived'],cleaned_data.loc[:,cleaned_data.columns=='Survived'],train_size=0.7)

# %%
X_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 435       1    0  14.0      1      2  120.0000         2
# 237       2    0   8.0      0      2   26.2500         2
# 767       3    0  30.5      0      0    7.7500         1
# 100       3    0  28.0      0      0    7.8958         2
# 338       3    1  45.0      0      0    8.0500         2
# ..      ...  ...   ...    ...    ...       ...       ...
# 506       2    0  33.0      0      2   26.0000         2
# 103       3    1  33.0      0      0    8.6542         2
# 602       1    1  28.0      0      0   42.4000         2
# 447       1    1  34.0      0      0   26.5500         2
# 638       3    0  41.0      0      5   39.6875         2
#
# [592 rows x 7 columns]

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\pumas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\pumas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lr.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
result=classification_report(y_test,pred)

# %%
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       161
#            1       0.73      0.73      0.73        93
#
#     accuracy                           0.80       254
#    macro avg       0.79      0.79      0.79       254
# weighted avg       0.80      0.80      0.80       254

# %%
from sklearn.metrics import confusion_matrix

# %%
result2=confusion_matrix(y_test,pred)

# %%
print(result2)
# Out:
# [[136  25]
#  [ 25  68]]

# %%
lr.predict([[3,1,30,0,2,50,2]])
# Out:
# C:\Users\pumas\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
ans
# Out:
# array([0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.8031496062992126
